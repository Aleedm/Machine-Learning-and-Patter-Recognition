# %%
from project.utils import load, cov, vcol, vrow, split
from project.LDA import binary_classification, LDA
from project.PCA import PCA
from project.plt import plot_hist, plot_gau_den_est
from project.gaussian_density_estimation import logpdf_GAU_ND, loglikelihood

# %%
data, labels = load('./project/train.csv')
data.shape, labels.shape

(DTR, LTR), (DVAL, LVAL) = split(data, labels)

# %% [markdown]
# # PCA and LDA

# %%
print(f"pca {1}: {binary_classification(data, labels, 6, True)}")
# Out:
# pca 1: (0.907, 0.093, 1814)

# %%
pca = PCA(data, 6)

# %%
for i in range(6):
    plot_hist(pca[0][i], labels, 50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Politecnico/Machine learning and pattern recognitions/Machine-Learning-and-Patter-Recognition/env/lib/python3.11/site-packages/PIL/ImageFile.py:536, in _save(im, fp, tile, bufsize)
#     535 try:
# --> 536     fh = fp.fileno()
#     537     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in range(6):
# ----> 2     plot_hist(pca[0][i], labels, 50)
#
# File ~/Politecnico/Machine learning and pattern recognitions/Machine-Learning-and-Patter-Recognition/project/plt.py:14, in plot_hist(feature, L, bins, threshold)
#      12     plt.axvline(x=threshold, color="green", linestyle="--", label="Threshold")
# ...

# %%
lda, _ = LDA(data, labels, 1)

# %%
plot_hist(lda[0], labels, 50)

# %%
binary_classification(data, labels, 1, pca = False, debug=False)

# %%
debug = False
accuracy, error, number_of_correct = binary_classification(data, labels, 6, pca=True, debug=debug)
print(f"pca {6}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")
print()
accuracy, error, number_of_correct = binary_classification(data, labels, 5, pca=True, debug=debug)
print(f"pca {5}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")
print()
accuracy, error, number_of_correct = binary_classification(data, labels, 4, pca=True, debug=debug)
print(f"pca {4}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")
print()
accuracy, error, number_of_correct = binary_classification(data, labels, 3, pca=True, debug=debug)
print(f"pca {3}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")
print()
accuracy, error, number_of_correct = binary_classification(data, labels, 2, pca=True, debug=debug)
print(f"pca {2}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")
print()
accuracy, error, number_of_correct = binary_classification(data, labels, 1, pca=True, debug=debug)
print(f"pca {1}, accuracy {accuracy}, error {error}, number of correct prediction: {number_of_correct}")

# %% [markdown]
# # Gaussian density estimation

# %%
import numpy as np

# %%
for i in range(6):
    D_t = DTR[:, LTR == 1][i]
    D_f = DTR[:, LTR == 0][i]
    plot_gau_den_est(D_t, D_f)

# %%
for c in [0, 1]:
    for i in range(6):
        D = DTR[:, LTR == c][i]
        plot_gau_den_est(D, project=(c, i))

# %%
from project.utils import load
from project.LDA import binary_classification, LDA
from project.PCA import PCA
from project.plt import plot_hist

# %%
data, labels = load('./project/train.csv')
data.shape, labels.shape
# Out:
# ((6, 6000), (6000,))

# %%
print(f"pca {1}: {binary_classification(data, labels, 1, True)}")
# Out:
# pca 1: (0.9115, 0.0885, 1823)

# %%
pca = PCA(data, 6)

# %%
for i in range(6):
    plot_hist(pca[0][i], labels, 50)

# %%
lda, _ = LDA(data, labels, 1)

# %%
plot_hist(lda[0], labels, 50)

# %%
binary_classification(data, labels, 1, pca = False, debug=False)
# Out:
# (0.9075, 0.0925, 1815)

# %%
debug = False
print(f"pca {6}: {binary_classification(data, labels, 6, pca=True, debug=debug)}")
print()
print(f"pca {5}: {binary_classification(data, labels, 5, pca=True, debug=debug)}")
print()
print(f"pca {4}: {binary_classification(data, labels, 4, pca=True, debug=debug)}")
print()
print(f"pca {3}: {binary_classification(data, labels, 3, pca=True, debug=debug)}")
print()
print(f"pca {2}: {binary_classification(data, labels, 2, pca=True, debug=debug)}")
print()
print(f"pca {1}: {binary_classification(data, labels, 1, pca=True, debug=debug)}")
# Out:
# pca 6: (0.9075, 0.0925, 1815)
#
# pca 5: (0.9065, 0.0935, 1813)
#
# pca 4: (0.9085, 0.0915, 1817)
#
# pca 3: (0.905, 0.095, 1810)
#
# pca 2: (0.9075, 0.0925, 1815)
#
# pca 1: (0.9115, 0.0885, 1823)
